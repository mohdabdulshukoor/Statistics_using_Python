# %% [markdown]
# # TASK 1

# %%
female_labours=46%

pt_female_labours=46*25/100=11.5     #as 25% of the females are for part-time out of 46% female

male_labours=100%-46%=54%            #considering females and male workers as 46% and 54% out of 100%

#But as given;

overall_pt_labours=174%              #whole American part-time labours

#conditional probability : p(A|B)=p(A n B)/p(B)

#considering;

p(A n B)=11.5%                       #part-time females within overall females(46%)

p(B)=17.5%                           #overall male & female American labours

so,the probabilty of the female worker is:

p(A|B)=p(A n B)/p(B)=11.5/17.5=0.65

# %% [markdown]
# # TASK 2

# %%
#respondents believing in increase in productivity by reducing noise:

p(A)=70%

#respondents believing in increase in productivity by increasing more storage space:

p(B)=67%

'''and in additiion,
respondents believing in increase in productivity by reducing noise as well as increasing storage space:'''

p(AnB)=56%

#here, the probabilty of respondents believing in increase in productivity by increasing more storage spaceare:

p(A n B)/p(B)=56/67=0.83

# %% [markdown]
# # TASK 3

# %%
import numpy as np
import pandas as pd
import statistics as st
from matplotlib import pyplot as plt

# %% [markdown]
# # Reading data:

# %%
gamesales_df=pd.read_csv('DS1_C5_S3_Sampling_Practice_GamesSales_Data.csv')
gamesales_df
# Out:
#                                  Game  Year             Genre  \
# 0                  Grand Theft Auto V  2016            Action
# 1           Call of Duty: Black Ops 3  2017           Shooter
# 2               Red Dead Redemption 2  2020  Action-Adventure
# 3                  Call of Duty: WWII  2019           Shooter
# 4                             FIFA 18  2019            Sports
# ..                                ...   ...               ...
# 704               Hyper Light Drifter  2019      Role-Playing
# 705                         Teslagrad  2016          Platform
# 706  Darius Burst: Chronicle Saviours  2019            Action
# 707   The Escapists: The Walking Dead  2018            Action
# 708                    Super Meat Boy  2018          Platform
#
#                Publisher  North_America_Sales_M$  Europe_Sales_M$  \
# 0         Rockstar Games                    6.06             9.71
# 1             Activision                    6.18             6.05
# ...

# %% [markdown]
# # Shape:

# %%
gamesales_df.shape
# Out:
# (709, 9)

# %% [markdown]
# # 3.1.1 Random Sampling without replacement

# %%
gamesales_df.sample(n=30,random_state=1)[:5]
# Out:
#                                                   Game  Year       Genre  \
# 189                           One Piece: Burning Blood  2018    Fighting
# 111                                           WWE 2K18  2019      Sports
# 551                         Sengoku Basara 4: Sumeragi  2017      Action
# 429  Earth Defense Force 2025.1: The Shadow of New ...  2017     Shooter
# 666                                 This Is The Police  2019  Simulation
#
#               Publisher  North_America_Sales_M$  Europe_Sales_M$  \
# 189  Namco Bandai Games                    0.21             0.26
# 111           2K Sports                    0.45             0.67
# 551              Capcom                    0.00             0.00
# 429         D3Publisher                    0.00             0.00
# 666          THQ Nordic                    0.01             0.00
#
#      Japan_Sales_M$  Other_Sales_M$  Global_Sales_M$
# 189            0.09            0.09             0.65
# ...

# %% [markdown]
# # 3.1.2 Random Sampling with replacement

# %%
gamesales_df.sample(n=30, replace=True, random_state=1)[:5]
# Out:
#                                                   Game  Year         Genre  \
# 37                                           Far Cry 5  2020        Action
# 235                                  Tales of Zestiria  2017  Role-Playing
# 72                             Need for Speed: Payback  2019        Racing
# 645  God Eater Off Shot: Tachibana Sakuya-hen Twin ...  2018        Action
# 144                           Injustice: Gods Among Us  2015      Fighting
#
#                                   Publisher  North_America_Sales_M$  \
# 37                                  Ubisoft                    1.44
# 235                      Namco Bandai Games                    0.18
# 72                          Electronic Arts                    0.62
# 645                      Namco Bandai Games                    0.00
# 144  Warner Bros. Interactive Entertainment                    0.46
#
#      Europe_Sales_M$  Japan_Sales_M$  Other_Sales_M$  Global_Sales_M$
# ...

# %% [markdown]
# # 3.1.3 Systematic Sampling

# %%
indexes=np.arange(0,len(gamesales_df), step=15)     #( START, STOP, STEP)
gamesales_df.iloc[indexes]
# Out:
#                                                   Game  Year  \
# 0                                   Grand Theft Auto V  2016
# 15                                           MineCraft  2016
# 30                                Call of Duty: Ghosts  2015
# 45                                        Watch Dogs 2  2018
# 60                                     Far Cry: Primal  2018
# 75                               PlayStation VR Worlds  2018
# 90                      Kingdom Hearts 1.5 + 2.5 Remix  2019
# 105                             Mass Effect: Andromeda  2019
# 120                    Metal Gear Solid: Ground Zeroes  2016
# 135                                    MLB The Show 18  2020
# 150                    Ni no Kuni II: Revenant Kingdom  2020
# 165                  Final Fantasy XIV: A Realm Reborn  2016
# 180                                      Dark Souls II  2017
# 195                                             NHL 15  2016
# ...

# %% [markdown]
# # 3.1.4 Stratified  Sampling with respect to year and genre

# %%
grouped_gs_df=gamesales_df.groupby(['Year'])
h=gamesales_df.Year.unique()
#g=gamesales_df.Genre.unique()
gs_Sample_df=pd.DataFrame()    #creating an empty DataFrame


for i in h:
    
    gs_data=grouped_gs_df.get_group(i)
    
    sample_df=gs_data.sample(n=30,
                             replace=True,
                             random_state=1) 
    
    gs_Sample_df=gs_Sample_df.append(sample_df,
                                     ignore_index=True)#Appending in the empty DataFrame which created before.
    
gs_Sample_df.head()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_3408\3866981835.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gs_Sample_df=gs_Sample_df.append(sample_df,
#                              Game  Year             Genre  \
# 0                 LEGO The Hobbit  2016  Action-Adventure
# 1                        NBA 2K15  2016            Sports
# 2                  Child of Light  2016      Role-Playing
# 3  Middle-Earth: Shadow of Mordor  2016            Action
# 4                   Omega Quintet  2016      Role-Playing
#
#                                 Publisher  North_America_Sales_M$  \
# 0  Warner Bros. Interactive Entertainment                    0.14
# 1                               2K Sports                    1.49
# 2                                 Ubisoft                    0.00
# 3  Warner Bros. Interactive Entertainment                    1.03
# ...

# %%
grouped_gs_df=gamesales_df.groupby(['Genre'])
h=gamesales_df.Genre.unique()
#g=gamesales_df.Year.unique()
gs_Sample_df=pd.DataFrame()    #creating an empty DataFrame


for i in h:
    
    gs_data=grouped_gs_df.get_group(i)
    
    sample_df=gs_data.sample(n=30,
                             replace=True,
                             random_state=1) 
    
    gs_Sample_df=gs_Sample_df.append(sample_df,
                                     ignore_index=True)#Appending in the empty DataFrame which created before.
    
gs_Sample_df.head()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_3408\3600653271.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gs_Sample_df=gs_Sample_df.append(sample_df,
#                                                 Game  Year   Genre  \
# 0  Dragon Quest Heroes: The World's Tree Woe and ...  2017  Action
# 1                          Unbox: Newbie's Adventure  2019  Action
# 2                                  Attack on Titan 2  2020  Action
# 3                         Vikings: Wolves of Midgard  2019  Action
# 4                Sengoku Basara: Sanada Yukimura-Den  2018  Action
#
#        Publisher  North_America_Sales_M$  Europe_Sales_M$  Japan_Sales_M$  \
# 0    Square Enix                    0.21             0.14            0.39
# 1    Merge Games                    0.03             0.00            0.00
# 2     Koei Tecmo                    0.09             0.04            0.06
# ...

# %% [markdown]
# # 3.1.5 Clustered Sampling with respect to year and genre

# %%
grouped_gy_df=gamesales_df.groupby(['Year'])
yrs=[2019,2020]
gy_Sample_df=pd.DataFrame()

for i in yrs:
    
    gy_data=grouped_gy_df.get_group(i)
    
    sample_gy_data=gy_data.sample(frac=.3,
                                    random_state=1)
    
    gy_Sample_df=gy_Sample_df.append(sample_gy_data,
                                     ignore_index=True)
    
gy_Sample_df.head()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_3408\557713751.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gy_Sample_df=gy_Sample_df.append(sample_gy_data,
#                                                 Game  Year             Genre  \
# 0  Yahari Game Demo Ore no Seishun Love-Kome wa M...  2019         Adventure
# 1                                  The Town of Light  2019         Adventure
# 2                                   Agents of Mayhem  2019            Action
# 3                                      Dead Rising 4  2019  Action-Adventure
# 4                                 This Is The Police  2019        Simulation
#
#            Publisher  North_America_Sales_M$  Europe_Sales_M$  Japan_Sales_M$  \
# 0                5pb                    0.00             0.00            0.01
# 1  Wired Productions                    0.02             0.00            0.00
# ...

# %%
grouped_gy_df=gamesales_df.groupby(['Genre'])
yrs=['Action','Sports']
gy_Sample_df=pd.DataFrame()

for i in yrs:
    
    gy_data=grouped_gy_df.get_group(i)
    
    sample_gy_data=gy_data.sample(frac=.3,
                                    random_state=1)
    
    gy_Sample_df=gy_Sample_df.append(sample_gy_data,
                                     ignore_index=True)
    
gy_Sample_df.head()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_3408\3693593086.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gy_Sample_df=gy_Sample_df.append(sample_gy_data,
#                                 Game  Year   Genre  \
# 0              Samurai Warriors 4-II  2017  Action
# 1                        Dead Rising  2018  Action
# 2           Lego Marvel Super Heroes  2015  Action
# 3  Dead Island Definitive Collection  2018  Action
# 4                    Yakuza Kiwami 2  2019  Action
#
#                                 Publisher  North_America_Sales_M$  \
# 0                              Tecmo Koei                    0.04
# 1                                  Capcom                    0.04
# 2  Warner Bros. Interactive Entertainment                    0.59
# 3                             Deep Silver                    0.09
# 4                                    Sega                    0.08
#
# ...

# %% [markdown]
# # TASK 3

# %% [markdown]
# # 3.2.1

# %%
#Sampling:
#sample_data10=car_df.sample(n=10, replace=True,random_state=1)
mm1=gamesales_df.sample(n=10, #sample10
             replace=True,random_state=1)

mm2=gamesales_df.sample(n=20, #sample20
                        random_state=1)

mm3=gamesales_df.sample(n=30, #sample30
                        random_state=1)

mm4=gamesales_df.sample(n=40, #sample40
                        random_state=1)

# %%
#Mean, Median, standard Deviation:

mm1a=st.mean(mm1['Global_Sales_M$'])
mm1b=st.stdev(mm1['Global_Sales_M$'])
mm1c=st.median(mm1['Global_Sales_M$'])
print("Sample-1 Mean= ",mm1a)
print("Sample-1 Median= ",mm1b)
print("Sample-1 Standard Deviation= ",mm1c)

mm2a=st.mean(mm2['Global_Sales_M$'])
mm2b=st.stdev(mm2['Global_Sales_M$'])
mm2c=st.median(mm2['Global_Sales_M$'])
print("Sample-2 Mean= ",mm2a)
print("Sample-2 Median= ",mm2b)
print("Sample-2 Standard Deviation= ",mm2c)
#
mm3a=st.mean(mm3['Global_Sales_M$'])
mm3b=st.stdev(mm3['Global_Sales_M$'])
mm3c=st.median(mm3['Global_Sales_M$'])
print("Sample-3 Mean= ",mm3a)
print("Sample-3 Median= ",mm3b)
print("Sample-3 Standard Deviation= ",mm3c)

mm4a=st.mean(mm4['Global_Sales_M$'])
mm4b=st.stdev(mm4['Global_Sales_M$'])
mm4c=st.median(mm4['Global_Sales_M$'])
print("Sample-4 Mean= ",mm4a)
print("Sample-4 Median= ",mm4b)
print("Sample-4 Standard Deviation= ",mm4c)
# Out:
# Sample-1 Mean=  0.925
# Sample-1 Median=  1.263612546102114
# Sample-1 Standard Deviation=  0.37
# Sample-2 Mean=  1.047
# Sample-2 Median=  1.9503956413750358
# Sample-2 Standard Deviation=  0.38
# Sample-3 Mean=  1.0453333333333334
# Sample-3 Median=  1.8386309249441335
# Sample-3 Standard Deviation=  0.185
# Sample-4 Mean=  0.87775
# Sample-4 Median=  1.6651102797081472
# Sample-4 Standard Deviation=  0.155

# %% [markdown]
# # 3.2.2

# %%
##Mean, Median, standard Deviation:(for the whole populaton)

gamesales_mm=st.mean(gamesales_df['Global_Sales_M$'])
gamesales_sd=st.stdev(gamesales_df['Global_Sales_M$'])

print("Mean gamesales_df :",gamesales_mm)
print("Standard deviation gamesales_df :",gamesales_sd)
# Out:
# Mean gamesales_df : 0.8398025387870239
# Standard deviation gamesales_df : 1.853914766367105

# %% [markdown]
# # 3.2.3

# %%
plt.hist(gamesales_df["Global_Sales_M$"],bins=7)
plt.xlabel("Global Sales")
plt.ylabel("Frequencies")
# Out:
# Text(0, 0.5, 'Frequencies')

# %%
#Sample graphs...

# %%
#mm1 sample:

plt.hist(mm1["Global_Sales_M$"],bins=7)
plt.xlabel("Global Sales")
plt.ylabel("Frequencies")
# Out:
# Text(0, 0.5, 'Frequencies')

# %%
#mm2 sample:

plt.hist(mm2["Global_Sales_M$"],bins=7)
plt.xlabel("Global Sales")
plt.ylabel("Frequencies")
# Out:
# Text(0, 0.5, 'Frequencies')

# %%
#mm3 sample:

plt.hist(mm3["Global_Sales_M$"],bins=7)
plt.xlabel("Global Sales")
plt.ylabel("Frequencies")
# Out:
# Text(0, 0.5, 'Frequencies')

# %%
#mm4 sample:

plt.hist(mm4["Global_Sales_M$"],bins=7)
plt.xlabel("Global Sales")
plt.ylabel("Frequencies")
# Out:
# Text(0, 0.5, 'Frequencies')

# %% [markdown]
# # Central Limit Theorem:

# %%
print("Average of the 10 Samples:",mm1a)
print("Average of the 40 Samples",mm4a)
print("Average of the Population",gamesales_mm)
# Out:
# Average of the 10 Samples: 0.925
# Average of the 40 Samples 0.87775
# Average of the Population 0.8398025387870239

# %%
'''
As the central limit theorem states that the sampling distribution of 
the meanapproaches a normal distribution,as the sample size increases.

so,here the above calculation and as per the illustrations we can conclude that;

This means that the sample mean is not systematically smaller or larger than the population average.
Or,if we repeatedly increase the sample values(actually an infinite number)of Samples,
the mean of the sample means would equal the population mean.

hence, "A Central Limit Theorem."

'''
